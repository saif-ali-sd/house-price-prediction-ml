# %%
# %run 01_data_exploration.ipynb
# %run 02_data_preprocessing.ipynb
# %run 03_feature_encoding.ipynb
# %run 04_model_training.ipynb
